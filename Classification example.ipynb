# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('indian_liver_patient.csv')
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df.dropna(inplace=True)

# %%
df_target=df['Dataset']
df_features=df.drop('Dataset',axis=1)

# %% [markdown]
# ## Importing of our library

# %%
import report

# %% [markdown]
# ### Report of default algorithms

# %%
report.report_classification(df_features,df_target)
# Out:
# Shape of the data : (579, 10)
# ---------------------------------------
# Encoding : Dummy Encoding
# ---------------------------------------
# Value count of target variable :
# Count of 0s is 414
# Count of 1s is 165
# ---------------------------------------
# Scaling : None
# ---------------------------------------
# Number of Datapoints : 5790
# ---------------------------------------
# Test size for train test split : 0.3
# ---------------------------------------
# Executing : LogisticRegression()
# Executing : GaussianNB()
# Executing : DecisionTreeClassifier()
# Executing : RandomForestClassifier()
# Executing : GradientBoostingClassifier()
# Executing : AdaBoostClassifier()
# Executing : XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
# ...

# %% [markdown]
# ### Report of required algorithms only

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
report.report_classification(df_features,df_target,algorithms=[RandomForestClassifier(max_depth=5),AdaBoostClassifier()])
# Out:
# Shape of the data : (579, 10)
# ---------------------------------------
# Encoding : Dummy Encoding
# ---------------------------------------
# Value count of target variable :
# Count of 0s is 414
# Count of 1s is 165
# ---------------------------------------
# Scaling : None
# ---------------------------------------
# Number of Datapoints : 5790
# ---------------------------------------
# Test size for train test split : 0.3
# ---------------------------------------
# Executing : RandomForestClassifier(max_depth=5)
# Executing : AdaBoostClassifier()
#                       Algorithm_name  Train_accuracy  Test_accuracy  \
# 0  RandomForestClassifier(max_depth=        0.864198       0.712644
# 1                 AdaBoostClassifier        0.824691       0.689655
#
#    Test_Roc_Auc_score  Test_recall  Test_precision
# 0            0.562996     0.229167        0.458333
# 1            0.618056     0.458333        0.440000

# %% [markdown]
# ### Using  different scaling techniques and encoding

# %%
report.report_classification(df_features,df_target,scaling='min-scalar',encode='label')
# Out:
# Shape of the data : (579, 10)
# ---------------------------------------
# Encoding : Label Encoding
# ---------------------------------------
# Value count of target variable :
# Count of 0s is 414
# Count of 1s is 165
# ---------------------------------------
# Scaling : None
# ---------------------------------------
# Number of Datapoints : 5790
# ---------------------------------------
# Test size for train test split : 0.3
# ---------------------------------------
# Executing : LogisticRegression()
# Executing : GaussianNB()
# Executing : DecisionTreeClassifier()
# Executing : RandomForestClassifier()
# Executing : GradientBoostingClassifier()
# Executing : AdaBoostClassifier()
# Executing : XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
# ...

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state=42)
df_features,df_target = sm.fit_resample(df_features, df_target)
df_target.value_counts()
# Out:
# 1    414
# 2    414
# Name: Dataset, dtype: int64

# %%
report.report_classification(df_features,df_target,test_size=0.2,change_data_type=True,encode='label')
# Out:
# Shape of the data : (828, 10)
# ---------------------------------------
# Encoding : Label Encoding
# ---------------------------------------
# Value count of target variable :
# Count of 0s is 414
# Count of 1s is 414
# ---------------------------------------
# Scaling : None
# ---------------------------------------
# Number of Datapoints : 8280
# ---------------------------------------
# Test size for train test split : 0.2
# ---------------------------------------
# Executing : LogisticRegression()
# Executing : GaussianNB()
# Executing : DecisionTreeClassifier()
# Executing : RandomForestClassifier()
# Executing : GradientBoostingClassifier()
# Executing : AdaBoostClassifier()
# Executing : XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
# ...
